# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

file = "C:\\Users\\lsauc\\Downloads\\Crimes2011-2019.csv"

df = pd.read_csv(file)
df.head()
# Out:
#   Unnamed: 0   Abr   Año          Estado  Mes       Municipio  id_estado  \
# 0    2011-01  Ags.  2011  Aguascalientes    1  Aguascalientes          1
# 1    2011-01  Ags.  2011  Aguascalientes    1        Asientos          1
# 2    2011-01  Ags.  2011  Aguascalientes    1        Calvillo          1
# 3    2011-01  Ags.  2011  Aguascalientes    1           Cosío          1
# 4    2011-01  Ags.  2011  Aguascalientes    1     Jesús María          1
#
#    id_municipio  Extorsion  HomicidioCulp  ...  rtExtorsion  rtHomicidioCulp  \
# 0        1001.0       10.0            4.0  ...     1.224257         0.489703
# 1        1002.0        0.0            0.0  ...     0.000000         0.000000
# 2        1003.0        0.0            1.0  ...     0.000000         1.810884
# 3        1004.0        0.0            0.0  ...     0.000000         0.000000
# 4        1005.0        1.0            2.0  ...     0.970516         1.941032
#
#    rtHomicidioDolo  rtLesiones  rtRoboCasa  rtRoboNegocio  rtRoboSinViol  \
# 0         0.979406   25.464545   18.853557      12.242570      21.424497
# 1         0.000000    4.288338    2.144169       6.432507       2.144169
# 2         0.000000    3.621768    3.621768       0.000000       7.243536
# 3         0.000000    0.000000   13.016565      13.016565       0.000000
# 4         0.000000   15.528254   22.321865       6.793611      12.616706
#
#    rtRoboVehi  rtRoboViol rtSecuestro
# 0   29.627019    4.529751         0.0
# 1    4.288338    0.000000         0.0
# 2    3.621768    3.621768         0.0
# 3   19.524847    0.000000         0.0
# 4   10.675674    0.970516         0.0
#
# [5 rows x 31 columns]

# %%
crime_df = df.loc[:,["Estado", "Extorsion", "HomicidioCulp", "HomicidioDolo", "Lesiones", "RoboCasa", "RoboNegocio", "RoboSinViol"
               , "RoboVehi", "RoboViol", "Secuestro", "Poblacion", "Fecha"]]

# %%
crime_df["Fecha"] = pd.to_datetime(crime_df["Fecha"])
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284928 entries, 0 to 284927
# Data columns (total 13 columns):
# Estado           284928 non-null object
# Extorsion        197496 non-null float64
# HomicidioCulp    197496 non-null float64
# HomicidioDolo    197496 non-null float64
# Lesiones         197496 non-null float64
# RoboCasa         197496 non-null float64
# RoboNegocio      197496 non-null float64
# RoboSinViol      197496 non-null float64
# RoboVehi         197496 non-null float64
# RoboViol         197496 non-null float64
# Secuestro        197496 non-null float64
# Poblacion        198408 non-null float64
# Fecha            284928 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), object(1)
# memory usage: 28.3+ MB

# %%
#crime_df.set_index(crime_df["Fecha"], inplace=True)

# %%
crime_by_state = crime_df.groupby("Estado").sum()

# %%
crime_by_state["Fecha"] = crime_df["Fecha"].max()

# %%
crime_by_state.head()
# Out:
#                      Extorsion  HomicidioCulp  HomicidioDolo  Lesiones  \
# Estado
# Aguascalientes           755.0         1645.0          517.0   33066.0
# Baja California         2413.0         2597.0        10857.0   52046.0
# Baja California Sur     1044.0          392.0         1253.0   10657.0
# Campeche                 287.0          693.0          614.0    1513.0
# Chiapas                  890.0         5548.0         3040.0    9819.0
#
#                      RoboCasa  RoboNegocio  RoboSinViol  RoboVehi  RoboViol  \
# Estado
# Aguascalientes        25793.0      15742.0      35727.0   21839.0    5564.0
# Baja California      119370.0      61258.0      41457.0  161823.0   18935.0
# Baja California Sur   23748.0        715.0      32641.0   11924.0    4829.0
# Campeche               1098.0        970.0       1466.0    2540.0    1189.0
# Chiapas                6821.0       3375.0       3133.0   13319.0    8045.0
#
#                      Secuestro     Poblacion      Fecha
# Estado
# Aguascalientes            42.0  1.543743e+08 2019-12-01
# Baja California          235.0  4.178577e+08 2019-12-01
# Baja California Sur        6.0  9.168649e+07 2019-12-01
# Campeche                  43.0  1.089085e+08 2019-12-01
# Chiapas                  135.0  4.882046e+08 2019-12-01

# %%
#Obtener los valores agregados por el total nacional
crime_df.set_index(crime_df["Fecha"], inplace=True)

# %%
crime_nacional = crime_df.resample('M').sum()
crime_nacional.head()
# Out:
#             Extorsion  HomicidioCulp  HomicidioDolo  Lesiones  RoboCasa  \
# Fecha
# 2011-01-31      308.0          677.0          847.0    8097.0    7985.0
# 2011-02-28      298.0          524.0          760.0    8150.0    7369.0
# 2011-03-31      360.0          579.0          887.0    9335.0    8451.0
# 2011-04-30      282.0          621.0          925.0    8488.0    7675.0
# 2011-05-31      359.0          602.0         1047.0    9451.0    7871.0
#
#             RoboNegocio  RoboSinViol  RoboVehi  RoboViol  Secuestro  \
# Fecha
# 2011-01-31       6091.0       8496.0   18371.0    5774.0       93.0
# 2011-02-28       5722.0       8459.0   17078.0    5684.0       84.0
# 2011-03-31       6137.0      10284.0   18857.0    6410.0       96.0
# 2011-04-30       5682.0       8825.0   16120.0    5628.0       92.0
# 2011-05-31       5915.0       9373.0   17549.0    6010.0       98.0
#
#                Poblacion
# Fecha
# 2011-01-31  9.613547e+07
# 2011-02-28  9.613547e+07
# 2011-03-31  9.613547e+07
# 2011-04-30  9.613547e+07
# 2011-05-31  9.613547e+07

# %%
#guardar data frame de crimen en un csv
crime_nacional.to_csv("Crimen_nal.csv")

# %%
grafica = crime_nacional.plot(y = ["Extorsion","HomicidioCulp","HomicidioDolo","Lesiones","RoboCasa","RoboNegocio","RoboSinViol","RoboVehi", "RoboViol", "Secuestro"])
#grafica

# %%
print(ax)
ax.set_ylim(ymin=0, ymax = )
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
